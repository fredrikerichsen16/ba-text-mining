# %%
import pandas as pd
import seaborn as sb
import os

# %%
df = pd.read_csv(os.path.abspath('data/BTC-USD.csv'))

# %%
df.head(20)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2015-01-01  320.434998  320.434998  314.002991  314.248993  314.248993
# 1   2015-01-02  314.079010  315.838989  313.565002  315.032013  315.032013
# 2   2015-01-03  314.846008  315.149994  281.082001  281.082001  281.082001
# 3   2015-01-04  281.145996  287.230011  257.612000  264.195007  264.195007
# 4   2015-01-05  265.084015  278.341003  265.084015  274.473999  274.473999
# 5   2015-01-06  274.610992  287.553009  272.696014  286.188995  286.188995
# 6   2015-01-07  286.076996  298.753998  283.079010  294.337006  294.337006
# 7   2015-01-08  294.135010  294.135010  282.174988  283.348999  283.348999
# 8   2015-01-09  282.382996  291.114014  280.532990  290.407990  290.407990
# 9   2015-01-10  287.303009  288.127014  273.966003  274.795990  274.795990
# 10  2015-01-11  274.608002  279.638000  265.039001  265.660004  265.660004
# ...

# %%
last_year = df[-365:-1]

# %%
sb.lineplot(x="Date", y="High", hue="Low", data=last_year)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
sb.relplot(x="Date", y="High", kind="line", data=last_year)
