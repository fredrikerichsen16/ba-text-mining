# %%
import pandas as pd
import sqlite3
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import os

# %%
conn = sqlite3.connect(os.path.abspath("data/alvin-files/bitcoin_simple.db"))
c = conn.cursor()
df = pd.read_sql("select date, text, tb_Subj from bitcoin_tb", conn)

# %%
df = df[:400000]

# %%
analyzer = SentimentIntensityAnalyzer()
#Add VADER metrics to dataframe
df['compound'] = [analyzer.polarity_scores(v)['compound'] for v in df['text']]
df['neg'] = [analyzer.polarity_scores(v)['neg'] for v in df['text']]
df['neu'] = [analyzer.polarity_scores(v)['neu'] for v in df['text']]
df['pos'] = [analyzer.polarity_scores(v)['pos'] for v in df['text']]
df.to_csv('bitcoin_tb_vd.csv')

# %%
df_sent = pd.read_csv('bitcoin_tb_vd.csv')

# %%
df_sent.head(30)
# Out:
#     Unnamed: 0                 date  \
# 0            0  2021-02-10 23:59:04
# 1            1  2021-02-10 23:58:48
# 2            2  2021-02-10 23:54:48
# 3            3  2021-02-10 23:54:33
# 4            4  2021-02-10 23:54:06
# 5            5  2021-02-10 23:53:30
# 6            6  2021-02-10 23:53:17
# 7            7  2021-02-10 23:52:42
# 8            8  2021-02-10 23:52:25
# 9            9  2021-02-10 23:52:08
# 10          10  2021-02-10 23:52:04
# 11          11  2021-02-10 23:51:25
# 12          12  2021-02-10 23:50:59
# 13          13  2021-02-10 23:50:30
# 14          14  2021-02-10 23:50:02
# 15          15  2021-02-10 23:48:38
# 16          16  2021-02-10 23:48:37
# 17          17  2021-02-10 23:47:32
# 18          18  2021-02-10 23:47:13
# 19          19  2021-02-10 23:46:39
# 20          20  2021-02-10 23:46:23
# 21          21  2021-02-10 23:46:17
# 22          22  2021-02-10 23:45:20
# 23          23  2021-02-10 23:45:03
# 24          24  2021-02-10 23:44:57
# 25          25  2021-02-10 23:44:43
# 26          26  2021-02-10 23:44:02
# 27          27  2021-02-10 23:44:02
# 28          28  2021-02-10 23:42:49
# 29          29  2021-02-10 23:42:22
#
#                                                  text   tb_Subj  compound  \
# 0   Blue Ridge Bank shares halted by NYSE after #b...  0.100000    0.2960
# 1   😎 Today, that's this #Thursday, we will do a "...  0.000000    0.4939
# 2   Guys evening, I have read this article about B...  0.000000    0.5719
# 3   $BTC A big chance in a billion! Price: \487264...  0.100000    0.3164
# 4   This network is secured by 9 508 nodes as of t...  0.100000    0.4019
# 5   💹 Trade #Crypto on #Binance \n\n📌 Enjoy #Cashb...  0.500000    0.4939
# 6   &lt;'fire' &amp; 'man'&gt;\n#Bitcoin #Crypto #...  0.000000    0.0000
# 7   🔄 Prices update in $EUR (1 hour):\n\n$BTC   - ...  0.000000   -0.2023
# 8   #BTC #Bitcoin #Ethereum #ETH #Crypto #cryptotr...  0.000000    0.0000
# 9   .@Tesla’s #bitcoin investment is revolutionary...  0.250000    0.0000
# 10  Annnd #btc #Bitcoin is headed even higher now....  0.500000    0.0000
# 11  🔄 Prices update in $USDT (1 hour):\n\n$BTC - 4...  0.000000   -0.2023
# 12  Join our first virtual crypto meetup of 2021 -...  0.333333    0.3595
# 13  #Bitcoin #BTC $BTC $GBTC $RIOT $MARA $ETH $ETH...  0.000000    0.0000
# 14  ⬆️⬆️ $BTC BUYING PRESSURE ALERT 📈 Price tradin...  0.000000    0.0000
# 15  Buy #Bitcoin with 5% LIFETIME cashback on fees...  0.000000    0.0000
# 16  @naval #BTC is unconfiscatable \n\nAll roads l...  0.000000    0.0000
# 17  $BTC A big chance in a million! Price: \489863...  0.100000    0.3164
# 18  #Bitcoin institutional demand accelerates in 2...  0.000000   -0.1280
# 19  Signal: $TFUEL\n#TFUEL #ThetaFuel #Binance #Cr...  0.000000    0.0000
# 20  $ADA Sky rocket 🔥🚀 #Patience 🔑\n$1 Soon !!! \n...  0.000000    0.0000
# 21  Forget all you know about #cryptocurrency \nTh...  0.300000   -0.4168
# 22  $ADA Sky rocket 🔥🚀 #Patience 🔑\n$1 Soon !!! \n...  0.000000    0.0000
# 23  #Bitcoin’s Rally Signals the Rise of Digital A...  0.200000    0.1779
# 24  The writing is on the wall, and you are ignori...  0.000000   -0.4019
# 25  #Bitcoin #BTC #ADA #DOT Mastercard Will Let Me...  0.000000    0.3818
# 26  After @Tesla: @Twitter considers adding #bitco...  0.000000    0.0000
# 27  $ASKO has been nothing short of a wild ride .....  0.310000   -0.1154
# 28  Let's go $yfi... Let's make this happen before...  0.000000    0.0000
# 29  Binance is the #1 crypto trading platform for ...  0.000000    0.0000
#
#       neg    neu    pos
# 0   0.000  0.855  0.145
# 1   0.000  0.849  0.151
# 2   0.000  0.773  0.227
# 3   0.000  0.840  0.160
# 4   0.000  0.891  0.109
# 5   0.000  0.824  0.176
# 6   0.000  1.000  0.000
# 7   0.149  0.851  0.000
# 8   0.000  1.000  0.000
# 9   0.000  1.000  0.000
# 10  0.000  1.000  0.000
# 11  0.149  0.851  0.000
# 12  0.000  0.878  0.122
# 13  0.000  1.000  0.000
# 14  0.174  0.652  0.174
# 15  0.000  1.000  0.000
# 16  0.000  1.000  0.000
# 17  0.000  0.840  0.160
# 18  0.097  0.903  0.000
# 19  0.000  1.000  0.000
# 20  0.000  1.000  0.000
# 21  0.127  0.873  0.000
# 22  0.000  1.000  0.000
# 23  0.000  0.909  0.091
# 24  0.184  0.816  0.000
# 25  0.000  0.860  0.140
# 26  0.000  1.000  0.000
# 27  0.062  0.938  0.000
# 28  0.000  1.000  0.000
# 29  0.000  1.000  0.000
